# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('../data/raw/Clean_Dataset.csv')
print(df.shape)
print(df.dtypes)
print(df.head())
# Out:
# (300153, 12)
# Unnamed: 0            int64
# airline                 str
# flight                  str
# source_city             str
# departure_time          str
# stops                   str
# arrival_time            str
# destination_city        str
# class                   str
# duration            float64
# days_left             int64
# price                 int64
# dtype: object
#    Unnamed: 0   airline   flight source_city departure_time stops  \
# 0           0  SpiceJet  SG-8709       Delhi        Evening  zero
# 1           1  SpiceJet  SG-8157       Delhi  Early_Morning  zero
# 2           2   AirAsia   I5-764       Delhi  Early_Morning  zero
# 3           3   Vistara   UK-995       Delhi        Morning  zero
# 4           4   Vistara   UK-963       Delhi        Morning  zero
#
#     arrival_time destination_city    class  duration  days_left  price
# 0          Night           Mumbai  Economy      2.17          1   5953
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0          0
# airline             0
# flight              0
# source_city         0
# departure_time      0
# stops               0
# arrival_time        0
# destination_city    0
# class               0
# duration            0
# days_left           0
# price               0
# dtype: int64

# %%
df['price'].describe()
# Out:
# count    300153.000000
# mean      20889.660523
# std       22697.767366
# min        1105.000000
# 25%        4783.000000
# 50%        7425.000000
# 75%       42521.000000
# max      123071.000000
# Name: price, dtype: float64

# %%
df.groupby(['source_city', 'destination_city'])['price'].mean().sort_values(ascending=False).head(10)
# Out:
# source_city  destination_city
# Chennai      Bangalore           25081.850454
# Kolkata      Chennai             23660.361040
# Bangalore    Kolkata             23500.061229
#              Chennai             23321.850078
# Mumbai       Bangalore           23147.873807
# Bangalore    Mumbai              23128.618672
# Mumbai       Chennai             22781.899112
# Chennai      Mumbai              22765.849647
# Kolkata      Bangalore           22744.808428
# Chennai      Kolkata             22669.932407
# Name: price, dtype: float64

# %%
df.groupby('airline')['price'].mean().sort_values()
# Out:
# airline
# AirAsia       4091.072742
# Indigo        5324.216303
# GO_FIRST      5652.007595
# SpiceJet      6179.278881
# Air_India    23507.019112
# Vistara      30396.536302
# Name: price, dtype: float64

# %%
plt.figure(figsize=(10,4))
sns.scatterplot(data=df.sample(5000), x='days_left', y='price', alpha=0.3)
plt.title('Price vs Days Until Departure')
plt.show()
